# %%
from PIL import Image, ImageDraw
import os
import sys

# %%
EPD_WIDTH = 128
EPD_HEIGHT = 296

# %%
plant_img = Image.open(os.path.join('../pic', 'plant.jpg'))
plant_img.size
# Out:
# (268, 188)

# %%
image = Image.new('1', (EPD_HEIGHT, EPD_WIDTH), 0)
draw = ImageDraw.Draw(image)
image.paste(plant_img, (14,-20))

# %%
image
# Out:
# <PIL.Image.Image image mode=1 size=296x128 at 0x27778D06400>

# %%
image2 = Image.new('1', (EPD_HEIGHT, EPD_WIDTH), 0)
plant_img = plant_img.resize((296,128))
draw2 = ImageDraw.Draw(image2)
image2.paste(plant_img, (0,0))
image2
# Out:
# <PIL.Image.Image image mode=1 size=296x128 at 0x27778D05668>

# %%
from PIL import ImageEnhance
image3 = ImageEnhance.Contrast(plant_img)
image3.enhance(2)
# Out:
# <PIL.Image.Image image mode=RGB size=296x128 at 0x2777909ED30>

# %%
image4 = Image.new('1', (EPD_HEIGHT, EPD_WIDTH), 0)
image4.paste(image3, (0,0))
image4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-18c08fe9c489> in <module>
#       1 image4 = Image.new('1', (EPD_HEIGHT, EPD_WIDTH), 0)
# ----> 2 image4.paste(image3, (0,0))
#       3 image4
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in paste(self, im, box, mask)
#    1506             else:
#    1507                 # FIXME: use self.size here?
# -> 1508                 raise ValueError("cannot determine region size; use 4-item box")
#    1509             box += (box[0] + size[0], box[1] + size[1])
#    1510
#
# ValueError: cannot determine region size; use 4-item box
