# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filepath = '../data/noise08_08_2020.csv'
#df = pd.read_csv(filepath, index_col = ['time'])
df = pd.read_csv(filepath)
df.head()
# Out:
#                          time    100-200    500-600  1000-1200  2000-3000
# 0  2020-08-08 00:00:18.892355  31.556314   9.729915   6.085272   4.889622
# 1  2020-08-08 00:01:19.005924  31.639061   9.592511   6.002540   4.461328
# 2  2020-08-08 00:02:19.111635  34.381992  12.632408  10.001539   8.844964
# 3  2020-08-08 00:03:19.194210  32.228640  11.126182   8.891207  11.375564
# 4  2020-08-08 00:04:19.272725  31.980586  10.086054   7.156570   5.883272

# %%
#y_data = df['100-200']
y_data = df['2000-3000']
#y_label = 'Humedad'
x_data = df['time']
x_label = 'Tiempo'
#title = "Sonidos 100-200"

# %%
fig, ax = plt.subplots()
ax.scatter(x_data, y_data, s = 30, color = '#539caf', alpha = 0.75)

ax.set_title(title)
#ax.set_xlabel(x_label)
ax.set_ylabel(y_label)
fig.autofmt_xdate()
