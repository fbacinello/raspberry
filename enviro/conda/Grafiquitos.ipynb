# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filepath = '../data_fem/2021_06_20enviro_not_suav_pres.csv'
#df = pd.read_csv(filepath, index_col = ['time'])
df = pd.read_csv(filepath)

# %%
y_data = df['humi']
y_label = 'Humedad'
x_data = df['time']
x_label = 'Tiempo'
title = "Humedad en el tiempo"

# %%
fig, ax = plt.subplots()
ax.scatter(x_data, y_data, s = 30, color = '#539caf', alpha = 0.75)

ax.set_title(title)
#ax.set_xlabel(x_label)
ax.set_ylabel(y_label)
fig.autofmt_xdate()

# %%
y_data = df['temp']
y_label = 'Temperatura'
x_data = df['time']
x_label = 'Tiempo'
title = "Temperatura en el tiempo"

# %%
fig, ax = plt.subplots()
ax.scatter(x_data, y_data, s = 30, color = '#539caf', alpha = 0.75)

ax.set_title(title)
#ax.set_xlabel(x_label)
ax.set_ylabel(y_label)
fig.autofmt_xdate()
