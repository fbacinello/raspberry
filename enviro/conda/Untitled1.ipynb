# %%
import pandas as pd
import matplotlib.pyplot as plt

filepath = '../data/enviro aire power.csv'
#df = pd.read_csv(filepath, index_col = ['time'])
df = pd.read_csv(filepath)
#df['time'] = pd.to_datetime(df['time'])
df.head()
# Out:
#                          time       temp       humi
# 0  2020-08-05 17:35:12.116574  26.711342  34.585582
# 1  2020-08-05 17:36:12.188112  26.261126  35.258290
# 2  2020-08-05 17:37:12.244223  26.870980  34.398519
# 3  2020-08-05 17:38:12.307385  27.078657  34.103249
# 4  2020-08-05 17:39:12.369323  27.128532  34.041771

# %%
y_data = df['humi']
y_label = 'Humedad'
x_data = df['time']
x_label = 'Tiempo'
title = "Humedad en el tiempo"

fig, ax = plt.subplots()
ax.scatter(x_data, y_data, s = 30, color = '#539caf', alpha = 0.75)

ax.set_title(title)
ax.set_xlabel(x_label)
ax.set_ylabel(y_label)
fig.autofmt_xdate()

# %%
y_data = df['temp']
y_label = 'Temperatura'
x_data = df['time']
x_label = 'Tiempo'
title = "Temperatura en el tiempo"

fig, ax = plt.subplots()
ax.scatter(x_data, y_data, s = 30, color = '#539caf', alpha = 0.75)

ax.set_title(title)
#ax.set_xlabel(x_label)
ax.set_ylabel(y_label)
fig.autofmt_xdate()
